# %% [markdown]
# >Chapter 42.
#
# [문제]
#
# 'Person'이라는 클래스를 선언하세요. 이 클래스는 name (이름)과 age (나이) 두 개의 속성을 갖습니다.<br>
#
# 그리고 'greet'라는 메소드를 갖고 있으며, 이 메소드는 "안녕하세요, 제 이름은 [name]입니다.
#
# 나이는 [age]살입니다."라는 메시지를 반환합니다.<br>
# 이 클래스를 사용하여 '홍길동'이라는 이름과 20살의 나이를 가진 'Person' 객체를 생성하고, 'greet' 메소드를 호출하여 메시지를 출력하세요.

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        # self.test = 'lol'
        return f"안녕하세요, 제 이름은 {self.name}입니다. 나이는 {self.age}살입니다."

    def test_func(self):
        print(self.test)


person = Person("홍길동", 20)
print(person.greet())
# person.test_func()
# Out:
# 안녕하세요, 제 이름은 홍길동입니다. 나이는 20살입니다.
# lol

# %% [markdown]
# >Chapter 43.
#
# [문제]
#
# 'Rectangle' 클래스를 작성하세요.
#
# 이 클래스는 높이(height)와 너비(width)를 속성으로 가지며, 생성자(__init__)를 통해 이 두 속성을 초기화합니다.
#
# 'area' 메소드를 추가하여 사각형의 면적을 계산하고 반환하도록 하세요. 높이가 10, 너비가 5인 사각형 객체를 생성하고,<br>
# 이 객체를 사용하여 면적을 계산해 출력하세요.

# %%
class Rectangle:
    def __init__(self, height, width):
        self.height = height
        self.width = width

    def area(self):
        return self.height * self.width


rectangle = Rectangle(10, 5)
print(rectangle.area())
# Out:
# 50

# %% [markdown]
# > Chapter 44.
#
# [문제]
#
# 'Book' 클래스를 선언하세요.
#
# 이 클래스는 title (제목)과 author (저자) 두 개의 속성을 갖습니다.
#
# 또한, 'describe_book'이라는 메소드를 추가하여, 호출 시 "제목: [title], 저자: [author]" 형식의 문자열을 출력하도록 하세요.
#
# 'Book' 객체를 하나 생성하고, 'describe_book' 메소드를 호출하여 해당 객체의 정보를 출력하세요.
#
# 이 문제는 클래스의 기본적인 사용법을 이해하고, 속성과 메소드를 정의하는 방법에 초점을 맞춥니다.

# %%
class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author

    def describe_book(self):
        print(f"제목: {self.title}, 저자: {self.author}")


my_book = Book("java의 정석", "홍길동")
my_book.describe_book()
# Out:
# 제목: java의 정석, 저자: 홍길동

# %% [markdown]
# > Chapter 45.
#
# [문제]
#
# 'Employee' 클래스를 선언하세요.
#
# 이 클래스는 클래스 변수로 'raise_amount'를 갖고 있으며, 기본값은 1.04입니다.
#
# 또한, 각 직원의 이름(name)과 급여(salary)를 속성으로 가지며, 'apply_raise' 메소드를 통해 급여에 'raise_amount'를 적용할 수 있어야 합니다.
#
# 'Employee' 클래스의 객체 두 개를 생성하고, 한 객체에만 'raise_amount'를 변경한 후, 두 객체의 급여를 증가시켜보세요.<br>
# 그리고 각 객체의 새로운 급여를 출력하세요.

# %%
class Employee:
    raise_amount = 1.04

    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    def apply_raise(self):
        self.salary = int(self.salary * self.raise_amount)


emp_1 = Employee("직원1", 50000)
emp_2 = Employee("직원2", 50000)

# Employee.raise_amount = 1.05
emp_1.raise_amount = 1.05
emp_1.apply_raise()
emp_2.apply_raise()

print(emp_1.salary)
print(emp_2.salary)
# Out:
# 52500
# 52000

# %% [markdown]
# > Chapter 46.
#
# [문제]
#
# 'Account' 클래스를 작성하세요.
#
# 이 클래스는 소유자(owner)와 잔액(balance)을 속성으로 가지며, 잔액은 프라이빗 변수로 선언합니다.
#
# 'deposit'와 'withdraw' 두 개의 메소드를 통해 잔액을 조작할 수 있도록 하세요.
#
# 이 때, 잔액은 음수가 될 수 없도록 체크해야 합니다. 'Account' 객체를 생성하고,<br>
# 입금 및 출금 작업을 시뮬레이션한 후, 최종 잔액을 출력하세요.

# %%
class Account:
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.__balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print('입금 성공')
        else:
            print('양수의 금액을 입력해주세요.')

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print("출금 성공")
        else:
            print(f'잔액이 {amount - self.__balance}원 부족합니다.')

    def __str__(self):
        return f'{self.owner}님의 잔액은 {self.__balance}원 입니다.'


account = Account("홍길동", 1000)
account.deposit(500)
account.withdraw(2000)
print(account)
# Out:
# 잔액이 500원 부족합니다.
# 홍길동님의 잔액은 1500원 입니다.

# %% [markdown]
# >Chapter 47.
#
# [문제]
#
# 'Vehicle'이라는 기본 클래스를 선언하세요.
#
# 이 클래스는 make (제조사)와 model (모델명) 두 개의 속성을 갖고, 생성자(__init__)를 통해 이 두 속성을 초기화합니다. 'display_info'라는 메소드를 추가하여, "이 차량은 [make]에서 제조한 [model]입니다."라는 메시지를 반환하도록 하세요.
#
# 'Truck'과 'Car' 두 개의 하위 클래스를 생성하고, 각 클래스는 'Vehicle' 클래스로부터 상속받습니다.
#
# 'Truck' 클래스에는 추가로 'payload' (적재량) 속성을, 'Car' 클래스에는 'seats' (좌석 수) 속성을 추가합니다. 각각의 하위 클래스에서 'display_info' 메소드는 기본 클래스의 메소드를 그대로 사용합니다.
#
# 'Truck'과 'Car' 객체 각각을 생성하고, 'display_info' 메소드를 호출하여 정보를 출력하세요.
#
# 또한, 각 객체의 추가 속성(적재량, 좌석 수)에 대한 정보도 출력하세요.
#
# 이 문제는 클래스의 상속 개념을 이해하고, 기본 클래스의 속성과 메소드를 하위 클래스가 어떻게 활용할 수 있는지 보여줍니다.
#
# 오버라이드는 필요하지 않으며, 각 하위 클래스의 고유한 속성을 추가하는 방법에 초점을 맞춥니다.

# %%
class Vehicle:
    def __init__(self, make, model):
        self.make = make
        self.model = model

    def __str__(self):
        return f"이 차량은 {self.make}에서 제조한 {self.model}입니다."

    def display_info(self):
        return f"이 차량은 {self.make}에서 제조한 {self.model}입니다."

class Truck(Vehicle):
    def __init__(self, make, model, payload):
        super().__init__(make, model)
        self.payload = payload

    def __str__(self):  # OverRiding
        return f"이 차량은 {self.make}에서 제조한 {self.model}이며, 적재량은 {self.payload}kg"

    def display_payload_info(self):
        return f"적재량: {self.payload}kg"  # 내용 답지 참고 #

class Car(Vehicle):
    def __init__(self, make, model, seats):
        super().__init__(make, model)
        self.seats = seats

    def __str__(self):
        return f"이 차량은 {self.make}에서 제조한 {self.model}이며, 좌석 수는 {self.seats}"

    def display_seats_info(self):
        return f"좌석 수: {self.seats}"  # 내용 답지 참고 #


truck = Truck("현대", "포터", 1000)
print(truck.display_info())
print(truck.display_payload_info())
print(truck)
print()

car = Car("기아", "K5", 5)
print(car.display_info())
print(car.display_seats_info())
print(car)
# Out:
# 이 차량은 현대에서 제조한 포터입니다.
# 적재량: 1000kg
# 이 차량은 현대에서 제조한 포터이며, 적재량은 1000kg
#
# 이 차량은 기아에서 제조한 K5입니다.
# 좌석 수: 5
# 이 차량은 기아에서 제조한 K5이며, 좌석 수는 5
